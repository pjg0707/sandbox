# %%
import matplotlib.pyplot as plt
import numpy as np
import skrf as rf
from skrf.data import ring_slot

#ring_slot = rf.Network('data/ring slot.s2p')
ring_slot
# Out:
# 2-Port Network: 'ring slot',  75.0-110.0 GHz, 201 pts, z0=[50.+0.j 50.+0.j]

# %%
plt.plot(ring_slot.f/1e9,20*np.log10(np.abs(ring_slot.s[::,0,0])))  # S11
plt.grid(visible=True)
plt.title('S parameters plotter')
plt.xlabel('Frequency (GHz)')
plt.ylabel('Return Loss (dB)')
# Out:
# Text(0, 0.5, 'Return Loss (dB)')
